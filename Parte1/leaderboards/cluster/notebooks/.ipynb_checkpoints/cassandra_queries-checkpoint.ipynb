# %%
# !pip install cassandra-driver
# Out:
# Collecting cassandra-driver
#   Downloading cassandra_driver-3.29.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (5.9 kB)
# Collecting geomet<0.3,>=0.1 (from cassandra-driver)
#   Downloading geomet-0.2.1.post1-py3-none-any.whl.metadata (1.0 kB)
# Requirement already satisfied: click in /opt/conda/lib/python3.11/site-packages (from geomet<0.3,>=0.1->cassandra-driver) (8.1.7)
# Requirement already satisfied: six in /opt/conda/lib/python3.11/site-packages (from geomet<0.3,>=0.1->cassandra-driver) (1.16.0)
# Downloading cassandra_driver-3.29.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (20.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 20.1/20.1 MB 14.5 MB/s eta 0:00:0000:0100:01
# Downloading geomet-0.2.1.post1-py3-none-any.whl (18 kB)
# Installing collected packages: geomet, cassandra-driver
# Successfully installed cassandra-driver-3.29.1 geomet-0.2.1.post1

# %%
from cassandra.cluster import Cluster
cluster = Cluster(['node1'], port = 9042)

# %%
session = cluster.connect()

# %% [markdown]
# ## Table Creation

# %%
session.execute("DROP KEYSPACE dungeons;")

# %%
# Create Keyspace
session.execute("""
      CREATE KEYSPACE IF NOT EXISTS dungeons WITH replication = {'class': 'SimpleStrategy', 'replication_factor': 3};
""")

# %%
cluster.metadata.keyspaces
# Out:
# {'system_auth': <cassandra.metadata.KeyspaceMetadata at 0x7f54aed24190>,
#  'system_schema': <cassandra.metadata.KeyspaceMetadata at 0x7f54ae9479d0>,
#  'bbdd2': <cassandra.metadata.KeyspaceMetadata at 0x7f54ae96e990>,
#  'system_distributed': <cassandra.metadata.KeyspaceMetadata at 0x7f54ae96efd0>,
#  'system': <cassandra.metadata.KeyspaceMetadata at 0x7f54ad534a50>,
#  'system_traces': <cassandra.metadata.KeyspaceMetadata at 0x7f54ad540e10>,
#  'system_views': <cassandra.metadata.KeyspaceMetadata at 0x7f54ad541cd0>,
#  'system_virtual_schema': <cassandra.metadata.KeyspaceMetadata at 0x7f54ad541e90>,
#  'dungeons': <cassandra.metadata.KeyspaceMetadata at 0x7f54ae9a2850>}

# %%
session.set_keyspace("dungeons")

# %%
print([e for e in session.execute('''DESCRIBE TABLES;''')])
# Out:
# [Row(keyspace_name='dungeons', type='table', name='hall_of_fame'), Row(keyspace_name='dungeons', type='table', name='top_horde'), Row(keyspace_name='dungeons', type='table', name='user_stats')]

# %%
session.execute('''CREATE TABLE top_horde (
    country text,
    event_id int,
    email text,
    user_name text,
    monster_id int,
    kill_id int,
    PRIMARY KEY ((country, event_id), email)
);''')

# %%
session.execute('''CREATE TABLE Hall_of_fame (
    country text,
    dungeon_id int,
    dungeon_name text,
    email text,
    user_name text,
    time_minutes int,
    date text,
    PRIMARY KEY ((country, dungeon_id), time_minutes))
    WITH CLUSTERING ORDER BY (time_minutes ASC);''')

# %%
session.execute('''CREATE TABLE User_stats (
    email text,
    dungeon_id int,
    time_minutes int,
    date text,
    PRIMARY KEY ((email, dungeon_id), time_minutes))
    WITH CLUSTERING ORDER BY (time_minutes ASC);''')

# %%
session.execute('''DROP TABLE Hall_of_fame;''')

# %%
session.execute('''DROP TABLE User_stats;''')

# %%
session.execute('''DROP TABLE top_horde;''')

# %% [markdown]
# ## Data Insertion

# %%
session.execute('''COPY Hall_of_fame (country, dungeon_id, dungeon_name, email, user_name, time_minutes, date, kill_id) FROM '/var/lib/cassandra/dungeon_completion.csv' WITH HEADER = true;''')
# Out:
# ---------------------------------------------------------------------------
# SyntaxException                           Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 session.execute('''COPY Hall_of_fame (country, dungeon_id, dungeon_name, email, user_name, time_minutes, date) FROM '/var/lib/cassandra/dungeon_completion.csv' WITH HEADER = true;''')
#
# File /opt/conda/lib/python3.11/site-packages/cassandra/cluster.py:2677, in cassandra.cluster.Session.execute()
#
# File /opt/conda/lib/python3.11/site-packages/cassandra/cluster.py:4956, in cassandra.cluster.ResponseFuture.result()
#
# SyntaxException: <Error from server: code=2000 [Syntax error in CQL query] message="line 1:0 no viable alternative at input 'COPY' ([COPY]...)">

# %% [markdown]
# ## Test the query

# %%
import json

def sortFn(dict):
  return dict['n_killed']


def topk_players(country, event_id, k):
    query =f'''SELECT email, user_name, COUNT(*) as n_killed from top_horde WHERE country='{country}' AND event_id={event_id} GROUP BY country, event_id, email;'''
    raw = [{'email': row.email, 'user_name': row.user_name, 'n_killed': row.n_killed} for row in session.execute(query)]
    sorted_data = sorted(raw, key=lambda x: x['n_killed'], reverse=True)
    top_k = json.dumps(sorted_data[:k], indent=4)
    return top_k

result = topk_players('de_DE', 0, 3)
print(result)
# Out:
# [
#     {
#         "email": "xullrich@example.org",
#         "user_name": "hartmanngloria",
#         "n_killed": 19
#     },
#     {
#         "email": "silvesterconradi@example.net",
#         "user_name": "bernhardmangold",
#         "n_killed": 15
#     },
#     {
#         "email": "gretelholsten@example.com",
#         "user_name": "johannekruschwitz",
#         "n_killed": 14
#     }
# ]

# %%
import json

def leaderboard_by_country(country):
    final = []
    for i in range(20):
        to_insert = {}
        
        query = f"SELECT dungeon_name, email, user_name, time_minutes, date from hall_of_fame WHERE country='{country}' AND dungeon_id={i} LIMIT 5;"
        aux = session.execute(query)
        dungeon_id = i
        res = [{'dungeon_name':row.dungeon_name, 'email': row.email, 'user_name': row.user_name,
        'time_minutes': row.time_minutes, 'date': row.date} for row in aux]
        dungeon_name = res[0]['dungeon_name']
        to_insert['dungeon_id'] = i
        to_insert['dungeon_name'] = dungeon_name
        to_insert['Top_5'] = []
        for e in res:
            del e['dungeon_name']
            to_insert['Top_5'].append(e)
            
        final.append(to_insert)
    return json.dumps(final, indent=4)
        

final = leaderboard_by_country('es_ES')
print(final)
# Out:
# [
#     {
#         "dungeon_id": 0,
#         "dungeon_name": "Burghap, Prison of the Jealous Hippies",
#         "Top_5": [
#             {
#                 "email": "macario68@example.com",
#                 "user_name": "julianesther",
#                 "time_minutes": 0,
#                 "date": "2022-03-25 05:52:29"
#             },
#             {
#                 "email": "reynaldo70@example.net",
#                 "user_name": "qcarretero",
#                 "time_minutes": 1,
#                 "date": "2021-03-01 15:17:24"
#             },
#             {
#                 "email": "zcisneros@example.org",
#                 "user_name": "ccorrea",
#                 "time_minutes": 2,
#                 "date": "2022-07-23 06:55:16"
#             },
#             {
#                 "email": "nelidaleiva@example.net",
#                 "user_name": "torrensemelina",
#                 "time_minutes": 3,
#                 "date": "2022-12-22 22:12:53"
#             },
#             {
#                 "email": "zparejo@example.com",
#                 "user_name": "malenagordillo",
#                 "time_minutes": 4,
#                 "date": "2022-02-23 07:45:16"
#             }
#         ]
#     },
#     {
#         "dungeon_id": 1,
#         "dungeon_name": "Burgstream, Culverts of the Bashful Sumo Wrestlers",
#         "Top_5": [
#             {
#                 "email": "sevillanomiguela@example.org",
#                 "user_name": "ocatala",
#                 "time_minutes": 0,
#                 "date": "2022-11-11 23:13:03"
#             },
#             {
#                 "email": "wredondo@example.net",
#                 "user_name": "afranch",
#                 "time_minutes": 1,
#                 "date": "2017-06-19 15:29:38"
#             },
#             {
#                 "email": "xavier36@example.org",
#                 "user_name": "dmendez",
#                 "time_minutes": 2,
#                 "date": "2022-12-10 18:13:08"
#             },
#             {
#                 "email": "yalmazan@example.org",
#                 "user_name": "noahurtado",
#                 "time_minutes": 3,
#                 "date": "2015-07-25 01:25:44"
#             },
#             {
#                 "email": "xvidal@example.com",
#                 "user_name": "monrealeugenio",
#                 "time_minutes": 4,
#                 "date": "2019-10-05 06:48:53"
#             }
#         ]
#     },
#     {
#         "dungeon_id": 2,
#         "dungeon_name": "Shadysparth, Hobble of the Wandering Stoners",
#         "Top_5": [
#             {
#                 "email": "wdonaire@example.com",
#                 "user_name": "leoncio76",
#                 "time_minutes": 0,
#                 "date": "2022-04-14 02:05:00"
#             },
#             {
#                 "email": "vmiranda@example.org",
#                 "user_name": "macario03",
#                 "time_minutes": 1,
#                 "date": "2022-12-12 08:14:47"
#             },
#             {
#                 "email": "wcoloma@example.net",
#                 "user_name": "kllabres",
#                 "time_minutes": 2,
#                 "date": "2022-08-09 15:10:26"
#             },
#             {
#                 "email": "wcoloma@example.net",
#                 "user_name": "kllabres",
#                 "time_minutes": 3,
#                 "date": "2022-05-19 00:20:19"
#             },
#             {
#                 "email": "violeta99@example.net",
#                 "user_name": "wilfredorodrigo",
#                 "time_minutes": 4,
#                 "date": "2022-05-14 08:01:15"
#             }
#         ]
#     },
#     {
#         "dungeon_id": 3,
#         "dungeon_name": "Wanton, Culverts of the Jealous Thieves",
#         "Top_5": [
#             {
#                 "email": "uferrero@example.net",
#                 "user_name": "llorenteconstanza",
#                 "time_minutes": 0,
#                 "date": "2013-12-20 14:31:34"
#             },
#             {
#                 "email": "zairaquerol@example.com",
#                 "user_name": "expositomario",
#                 "time_minutes": 1,
#                 "date": "2021-01-09 03:39:41"
#             },
#             {
#                 "email": "zvidal@example.com",
#                 "user_name": "rubenestrada",
#                 "time_minutes": 2,
#                 "date": "2021-01-14 11:44:22"
#             },
#             {
#                 "email": "zborrell@example.org",
#                 "user_name": "marcos77",
#                 "time_minutes": 3,
#                 "date": "2022-03-15 18:41:35"
#             },
#             {
#                 "email": "zgrau@example.com",
#                 "user_name": "macarenaposada",
#                 "time_minutes": 4,
#                 "date": "2021-11-28 01:31:10"
#             }
#         ]
#     },
#     {
#         "dungeon_id": 4,
#         "dungeon_name": "Withystream, Castle of the Screeching Otaku",
#         "Top_5": [
#             {
#                 "email": "valentinahoyos@example.net",
#                 "user_name": "federico58",
#                 "time_minutes": 0,
#                 "date": "2016-06-15 19:08:36"
#             },
#             {
#                 "email": "vcasals@example.org",
#                 "user_name": "nestor81",
#                 "time_minutes": 1,
#                 "date": "2022-11-25 05:26:08"
#             },
#             {
#                 "email": "vmiranda@example.org",
#                 "user_name": "macario03",
#                 "time_minutes": 2,
#                 "date": "2022-03-11 00:26:41"
#             },
#             {
#                 "email": "vsolera@example.net",
#                 "user_name": "maribelvillalobos",
#                 "time_minutes": 3,
#                 "date": "2022-08-17 23:19:24"
#             },
#             {
#                 "email": "vmiranda@example.org",
#                 "user_name": "macario03",
#                 "time_minutes": 4,
#                 "date": "2022-08-25 08:30:04"
#             }
#         ]
#     },
#     {
#         "dungeon_id": 5,
#         "dungeon_name": "Fenwater, Hobble of the Fierce Furries",
#         "Top_5": [
#             {
#                 "email": "yolanda14@example.com",
#                 "user_name": "earribas",
#                 "time_minutes": 0,
#                 "date": "2020-02-06 03:02:26"
#             },
#             {
#                 "email": "yzaragoza@example.org",
#                 "user_name": "voliver",
#                 "time_minutes": 1,
#                 "date": "2022-01-22 06:17:49"
#             },
#             {
#                 "email": "zparejo@example.com",
#                 "user_name": "malenagordillo",
#                 "time_minutes": 2,
#                 "date": "2022-06-05 08:37:36"
#             },
#             {
#                 "email": "zcisneros@example.org",
#                 "user_name": "ccorrea",
#                 "time_minutes": 3,
#                 "date": "2022-09-17 20:20:59"
#             },
#             {
#                 "email": "zrios@example.com",
#                 "user_name": "sosimo68",
#                 "time_minutes": 4,
#                 "date": "2018-09-29 02:19:26"
#             }
#         ]
#     },
#     {
#         "dungeon_id": 6,
#         "dungeon_name": "Arvaleclock, Dungeon of the Snobbish Scientists",
#         "Top_5": [
#             {
#                 "email": "santamariacrescencia@example.org",
#                 "user_name": "landaitziar",
#                 "time_minutes": 0,
#                 "date": "2019-01-28 23:19:01"
#             },
#             {
#                 "email": "salamancabernarda@example.net",
#                 "user_name": "silvia75",
#                 "time_minutes": 1,
#                 "date": "2021-12-22 03:59:43"
#             },
#             {
#                 "email": "santiagoemilio@example.net",
#                 "user_name": "lilianalozano",
#                 "time_minutes": 2,
#                 "date": "2020-05-29 04:28:11"
#             },
#             {
#                 "email": "santiagoemilio@example.net",
#                 "user_name": "lilianalozano",
#                 "time_minutes": 3,
#                 "date": "2022-07-06 03:50:37"
#             },
#             {
#                 "email": "sanmiguelromulo@example.net",
#                 "user_name": "melendezemigdio",
#                 "time_minutes": 4,
#                 "date": "2021-12-26 04:29:30"
#             }
#         ]
#     },
#     {
#         "dungeon_id": 7,
#         "dungeon_name": "Watergarth, Stockade of the Feminist Presidents",
#         "Top_5": [
#             {
#                 "email": "rpou@example.net",
#                 "user_name": "vilmaespada",
#                 "time_minutes": 0,
#                 "date": "2022-12-02 17:46:29"
#             },
#             {
#                 "email": "torresmaura@example.org",
#                 "user_name": "dmesa",
#                 "time_minutes": 1,
#                 "date": "2022-10-04 23:15:54"
#             },
#             {
#                 "email": "ttejedor@example.net",
#                 "user_name": "ballesterromulo",
#                 "time_minutes": 2,
#                 "date": "2022-05-23 00:55:52"
#             },
#             {
#                 "email": "trobles@example.org",
#                 "user_name": "wmaldonado",
#                 "time_minutes": 3,
#                 "date": "2021-05-08 08:41:00"
#             },
#             {
#                 "email": "torresmaura@example.org",
#                 "user_name": "dmesa",
#                 "time_minutes": 4,
#                 "date": "2022-10-04 12:26:20"
#             }
#         ]
#     },
#     {
#         "dungeon_id": 8,
#         "dungeon_name": "Spleensparth, Mines of the Panicky Otaku",
#         "Top_5": [
#             {
#                 "email": "rodriguezbernabe@example.org",
#                 "user_name": "berrocalamaro",
#                 "time_minutes": 0,
#                 "date": "2014-06-18 11:20:47"
#             },
#             {
#                 "email": "xsalinas@example.org",
#                 "user_name": "ovidiocomas",
#                 "time_minutes": 1,
#                 "date": "2018-03-14 21:56:20"
#             },
#             {
#                 "email": "xvidal@example.com",
#                 "user_name": "monrealeugenio",
#                 "time_minutes": 2,
#                 "date": "2022-05-20 22:47:16"
#             },
#             {
#                 "email": "xreal@example.org",
#                 "user_name": "ktur",
#                 "time_minutes": 3,
#                 "date": "2022-05-12 23:31:19"
#             },
#             {
#                 "email": "yalmazan@example.org",
#                 "user_name": "noahurtado",
#                 "time_minutes": 4,
#                 "date": "2020-12-14 00:15:48"
#             }
#         ]
#     },
#     {
#         "dungeon_id": 9,
#         "dungeon_name": "Alaunstream, Pit of the Jolly Scientists",
#         "Top_5": [
#             {
#                 "email": "zparejo@example.com",
#                 "user_name": "malenagordillo",
#                 "time_minutes": 0,
#                 "date": "2022-02-17 12:58:14"
#             },
#             {
#                 "email": "zrios@example.com",
#                 "user_name": "sosimo68",
#                 "time_minutes": 1,
#                 "date": "2019-03-02 03:35:59"
#             },
#             {
#                 "email": "zvidal@example.com",
#                 "user_name": "rubenestrada",
#                 "time_minutes": 2,
#                 "date": "2020-08-15 12:31:30"
#             },
#             {
#                 "email": "zvidal@example.com",
#                 "user_name": "rubenestrada",
#                 "time_minutes": 3,
#                 "date": "2021-05-19 11:49:39"
#             },
#             {
#                 "email": "zvidal@example.com",
#                 "user_name": "rubenestrada",
#                 "time_minutes": 4,
#                 "date": "2022-06-20 08:08:54"
#             }
#         ]
#     },
#     {
#         "dungeon_id": 10,
#         "dungeon_name": "Corriedal, Sewers of the Terrible Emperors",
#         "Top_5": [
#             {
#                 "email": "zvidal@example.com",
#                 "user_name": "rubenestrada",
#                 "time_minutes": 0,
#                 "date": "2021-05-26 17:33:31"
#             },
#             {
#                 "email": "zvidal@example.com",
#                 "user_name": "rubenestrada",
#                 "time_minutes": 1,
#                 "date": "2022-11-24 19:50:02"
#             },
#             {
#                 "email": "ztirado@example.org",
#                 "user_name": "urbano63",
#                 "time_minutes": 2,
#                 "date": "2022-09-20 18:46:44"
#             },
#             {
#                 "email": "zvidal@example.com",
#                 "user_name": "rubenestrada",
#                 "time_minutes": 3,
#                 "date": "2020-09-02 21:49:09"
#             },
#             {
#                 "email": "zvall@example.com",
#                 "user_name": "batllebeatriz",
#                 "time_minutes": 4,
#                 "date": "2022-10-12 10:09:51"
#             }
#         ]
#     },
#     {
#         "dungeon_id": 11,
#         "dungeon_name": "Bentalaun, Vault of the Old-Fashioned Pirates",
#         "Top_5": [
#             {
#                 "email": "montanagema@example.org",
#                 "user_name": "leticia60",
#                 "time_minutes": 0,
#                 "date": "2022-11-11 18:14:59"
#             },
#             {
#                 "email": "mrozas@example.org",
#                 "user_name": "basevaristo",
#                 "time_minutes": 1,
#                 "date": "2022-11-05 17:43:38"
#             },
#             {
#                 "email": "moreno76@example.net",
#                 "user_name": "ucabanillas",
#                 "time_minutes": 2,
#                 "date": "2019-06-15 21:06:35"
#             },
#             {
#                 "email": "mpastor@example.net",
#                 "user_name": "cjover",
#                 "time_minutes": 3,
#                 "date": "2017-10-16 09:57:17"
#             },
#             {
#                 "email": "mrozas@example.org",
#                 "user_name": "basevaristo",
#                 "time_minutes": 4,
#                 "date": "2022-12-11 22:29:10"
#             }
#         ]
#     },
#     {
#         "dungeon_id": 12,
#         "dungeon_name": "Strathglass, Mausoleum of the Repulsive Ninjas",
#         "Top_5": [
#             {
#                 "email": "pepe48@example.org",
#                 "user_name": "emigdiogalan",
#                 "time_minutes": 0,
#                 "date": "2022-04-24 03:51:32"
#             },
#             {
#                 "email": "primitivobenavente@example.org",
#                 "user_name": "acuellar",
#                 "time_minutes": 1,
#                 "date": "2015-11-16 23:43:08"
#             },
#             {
#                 "email": "pruano@example.org",
#                 "user_name": "albertcastrillo",
#                 "time_minutes": 2,
#                 "date": "2022-11-12 22:48:01"
#             },
#             {
#                 "email": "ponceandrea@example.com",
#                 "user_name": "rmorillo",
#                 "time_minutes": 3,
#                 "date": "2017-12-22 23:20:49"
#             },
#             {
#                 "email": "priscilacarnero@example.com",
#                 "user_name": "albertcastrillo",
#                 "time_minutes": 4,
#                 "date": "2022-11-02 06:14:06"
#             }
#         ]
#     },
#     {
#         "dungeon_id": 13,
#         "dungeon_name": "Greatcliffe, Castle of the Magnificent Sumo Wrestlers",
#         "Top_5": [
#             {
#                 "email": "sedanocarmen@example.net",
#                 "user_name": "gabrielagusti",
#                 "time_minutes": 0,
#                 "date": "2022-05-31 05:16:25"
#             },
#             {
#                 "email": "santiagoemilio@example.net",
#                 "user_name": "lilianalozano",
#                 "time_minutes": 1,
#                 "date": "2021-03-05 11:33:55"
#             },
#             {
#                 "email": "zborrell@example.org",
#                 "user_name": "marcos77",
#                 "time_minutes": 2,
#                 "date": "2020-12-05 01:01:41"
#             },
#             {
#                 "email": "yustealberto@example.org",
#                 "user_name": "perla88",
#                 "time_minutes": 3,
#                 "date": "2022-08-06 04:08:20"
#             },
#             {
#                 "email": "zgarzon@example.net",
#                 "user_name": "teodora24",
#                 "time_minutes": 4,
#                 "date": "2022-12-23 00:38:59"
#             }
#         ]
#     },
#     {
#         "dungeon_id": 14,
#         "dungeon_name": "Schyppegarth, Laboratory of the Sticky Robots",
#         "Top_5": [
#             {
#                 "email": "xvelez@example.com",
#                 "user_name": "boschsilvia",
#                 "time_minutes": 0,
#                 "date": "2014-11-04 02:24:41"
#             },
#             {
#                 "email": "xsanmiguel@example.com",
#                 "user_name": "lujanpastora",
#                 "time_minutes": 1,
#                 "date": "2022-12-22 07:51:42"
#             },
#             {
#                 "email": "xvidal@example.com",
#                 "user_name": "monrealeugenio",
#                 "time_minutes": 2,
#                 "date": "2022-04-01 21:47:14"
#             },
#             {
#                 "email": "xsanmiguel@example.com",
#                 "user_name": "lujanpastora",
#                 "time_minutes": 3,
#                 "date": "2022-04-25 12:40:49"
#             },
#             {
#                 "email": "xsoto@example.org",
#                 "user_name": "ncorral",
#                 "time_minutes": 4,
#                 "date": "2022-09-14 20:46:02"
#             }
#         ]
#     },
#     {
#         "dungeon_id": 15,
#         "dungeon_name": "Corrieclock, Pit of the Sexy Unknowns",
#         "Top_5": [
#             {
#                 "email": "leocadiopinto@example.net",
#                 "user_name": "vallmarcos",
#                 "time_minutes": 0,
#                 "date": "2022-03-02 22:48:57"
#             },
#             {
#                 "email": "xbarrio@example.com",
#                 "user_name": "natanaelfernandez",
#                 "time_minutes": 1,
#                 "date": "2021-11-02 11:43:19"
#             },
#             {
#                 "email": "xfrancisco@example.org",
#                 "user_name": "huertasglauco",
#                 "time_minutes": 2,
#                 "date": "2022-11-09 04:13:09"
#             },
#             {
#                 "email": "xreal@example.org",
#                 "user_name": "ileanaperales",
#                 "time_minutes": 3,
#                 "date": "2022-08-14 18:17:03"
#             },
#             {
#                 "email": "xreal@example.org",
#                 "user_name": "ileanaperales",
#                 "time_minutes": 4,
#                 "date": "2022-08-22 02:48:44"
#             }
#         ]
#     },
#     {
#         "dungeon_id": 16,
#         "dungeon_name": "Dalshady, Cave of the Old-Fashioned Otaku",
#         "Top_5": [
#             {
#                 "email": "lalo64@example.com",
#                 "user_name": "ucampos",
#                 "time_minutes": 0,
#                 "date": "2022-07-04 15:20:20"
#             },
#             {
#                 "email": "zvidal@example.com",
#                 "user_name": "rubenestrada",
#                 "time_minutes": 1,
#                 "date": "2021-03-05 21:56:06"
#             },
#             {
#                 "email": "lastraemperatriz@example.net",
#                 "user_name": "severiano88",
#                 "time_minutes": 2,
#                 "date": "2022-10-14 09:05:44"
#             },
#             {
#                 "email": "zparejo@example.com",
#                 "user_name": "malenagordillo",
#                 "time_minutes": 3,
#                 "date": "2022-05-05 18:14:33"
#             },
#             {
#                 "email": "zvidal@example.com",
#                 "user_name": "rubenestrada",
#                 "time_minutes": 4,
#                 "date": "2021-04-05 23:44:41"
#             }
#         ]
#     },
#     {
#         "dungeon_id": 17,
#         "dungeon_name": "Marshgreat, Catacombs of the Wandering Degenerates",
#         "Top_5": [
#             {
#                 "email": "valcolea@example.net",
#                 "user_name": "teodosio87",
#                 "time_minutes": 0,
#                 "date": "2021-11-20 23:40:12"
#             },
#             {
#                 "email": "vverdu@example.org",
#                 "user_name": "consuelo55",
#                 "time_minutes": 1,
#                 "date": "2022-10-30 20:51:00"
#             },
#             {
#                 "email": "wcoloma@example.net",
#                 "user_name": "kllabres",
#                 "time_minutes": 2,
#                 "date": "2022-03-31 12:48:22"
#             },
#             {
#                 "email": "vasco28@example.net",
#                 "user_name": "salome08",
#                 "time_minutes": 3,
#                 "date": "2020-01-19 18:52:06"
#             },
#             {
#                 "email": "wcoloma@example.net",
#                 "user_name": "kllabres",
#                 "time_minutes": 4,
#                 "date": "2022-12-25 21:36:19"
#             }
#         ]
#     },
#     {
#         "dungeon_id": 18,
#         "dungeon_name": "Garthwort, Mines of the Elderly Emperors",
#         "Top_5": [
#             {
#                 "email": "wredondo@example.net",
#                 "user_name": "afranch",
#                 "time_minutes": 0,
#                 "date": "2021-04-27 18:48:54"
#             },
#             {
#                 "email": "tomasa83@example.org",
#                 "user_name": "cuencaclaudia",
#                 "time_minutes": 1,
#                 "date": "2022-03-06 10:20:21"
#             },
#             {
#                 "email": "trobles@example.org",
#                 "user_name": "wmaldonado",
#                 "time_minutes": 2,
#                 "date": "2022-12-03 04:44:45"
#             },
#             {
#                 "email": "trobles@example.org",
#                 "user_name": "wmaldonado",
#                 "time_minutes": 3,
#                 "date": "2022-10-17 21:10:11"
#             },
#             {
#                 "email": "trobles@example.org",
#                 "user_name": "wmaldonado",
#                 "time_minutes": 4,
#                 "date": "2021-03-21 09:55:43"
#             }
#         ]
#     },
#     {
#         "dungeon_id": 19,
#         "dungeon_name": "Dalhylles, Culverts of the Grumpy Bandits",
#         "Top_5": [
#             {
#                 "email": "tiradoiban@example.org",
#                 "user_name": "cosmerio",
#                 "time_minutes": 0,
#                 "date": "2022-07-27 17:48:33"
#             },
#             {
#                 "email": "tmercader@example.com",
#                 "user_name": "robertavergara",
#                 "time_minutes": 1,
#                 "date": "2022-11-11 10:54:09"
#             },
#             {
#                 "email": "torresmaura@example.org",
#                 "user_name": "dmesa",
#                 "time_minutes": 2,
#                 "date": "2022-06-28 11:00:14"
#             },
#             {
#                 "email": "torobrigida@example.com",
#                 "user_name": "sanchocastillo",
#                 "time_minutes": 3,
#                 "date": "2022-04-09 19:55:02"
#             },
#             {
#                 "email": "tomasa83@example.org",
#                 "user_name": "cuencaclaudia",
#                 "time_minutes": 4,
#                 "date": "2022-08-28 04:58:07"
#             }
#         ]
#     }
# ]

# %%
def user_stats_per_dun(email, dungeon_id):
    final = []
    query = f"select time_minutes, date from user_stats where email='{email}' AND dungeon_id={dungeon_id};"
    aux = session.execute(query)
    for row in aux:
        final.append({'time_minutes':row.time_minutes, 'date':row.date})
        
    return json.dumps(final, indent=4)
result = user_stats_per_dun('macario68@example.com',0)
print(result)
# Out:
# [
#     {
#         "time_minutes": 0,
#         "date": "2022-03-25 05:52:29"
#     },
#     {
#         "time_minutes": 17,
#         "date": "2022-09-18 18:48:40"
#     },
#     {
#         "time_minutes": 19,
#         "date": "2022-06-11 15:11:25"
#     },
#     {
#         "time_minutes": 20,
#         "date": "2022-03-16 12:45:05"
#     },
#     {
#         "time_minutes": 27,
#         "date": "2022-05-18 20:01:22"
#     },
#     {
#         "time_minutes": 29,
#         "date": "2021-11-09 05:14:13"
#     },
#     {
#         "time_minutes": 34,
#         "date": "2022-06-24 01:07:16"
#     },
#     {
#         "time_minutes": 40,
#         "date": "2022-03-06 02:01:56"
#     },
#     {
#         "time_minutes": 46,
#         "date": "2021-10-10 01:41:04"
#     }
# ]
